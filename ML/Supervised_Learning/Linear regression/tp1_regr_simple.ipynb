# %%
import pandas as pd
import matplotlib.pyplot as plt
from  sklearn.linear_model import LinearRegression
from  sklearn.model_selection import train_test_split
from  sklearn.metrics import mean_squared_error,r2_score

# %%
df = pd.read_csv("database-salaries.csv")
print(df.head());
#variable inndependante (1 seul colonne)
x= df[['years_of_experience']]
#affiche donnees input
print(x);
y= df['salary']
print(y);
# Out:
#    years_of_experience  salary
# 0                    5    3150
# 1                    9    3787
# 2                    4    2991
# 3                   10    4551
# 4                    8    3540
#     years_of_experience
# 0                     5
# 1                     9
# 2                     4
# 3                    10
# 4                     8
# ..                  ...
# 95                    4
# 96                    4
# 97                    2
# 98                    7
# 99                    2
#
# [100 rows x 1 columns]
# 0     3150
# 1     3787
# 2     2991
# 3     4551
# 4     3540
#       ...
# 95    2884
# 96    2810
# 97    2488
# 98    3661
# 99    2496
# Name: salary, Length: 100, dtype: int64

# %%
x_train,x_test,y_train,y_test =train_test_split(
    x,y,test_size =0.2 ,random_state =42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#PREDiction
y_pred =model.predict(x_test)
print("coefficient ( β1) :",model.coef_[0])
print("intercept ( β0) :",model.intercept_)
print("R2 score :",r2_score(y_test,y_pred))
print("MSE :", mean_squared_error(y_test,y_pred))
# Out:
# coefficient ( β1) : 189.68286151491958
# intercept ( β0) : 2246.074120122418
# R2 score : 0.9373858925288361
# MSE : 22766.87455327615

# %%
plt.scatter(x,y)
plt.plot(x,model.predict(x),color = 'red')
plt.xlabel('years_of_experience')
plt.ylabel('salary')
plt.title('simple Linear Regression')
# Out:
# Text(0.5, 1.0, 'simple Linear Regression')

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in /home/abdellah/anaconda3/lib/python3.13/site-packages (1.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib 
model.fit(x_train, y_train)
joblib.dump(model,"salary_model.pkl")
print('suvgard avec succes')
# Out:
# suvgard avec succes
